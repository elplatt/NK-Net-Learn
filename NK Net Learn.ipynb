# %%
# %pylab inline
import sys
import numpy as np
import pandas as pd
import scipy.stats as spstats
import elp_networks.algorithms as elpalg
import elp_nkmodel as elpnk
import net
import simulator

import strategy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
N = 2000
K = 3
D = 1
rewire_values = 5
per_rewire = 50

conform_perf = []
best_perf = []
loc_cons_perf = []
loc_conform_perf = []
diameter = []
meanpath = []
degree = []
rewire = []
best_values = []
conform_values = []
loc_cons_values = []
loc_conform_values = []

for r in range(rewire_values):
    r = float(r) / float(rewire_values - 1)
    for i in range(per_rewire):
        rewire.append(r)
        print "Rewire %f" % r
        m = elpnk.NK(N, K)
        # Generate network from NK structure
        edges_node_loc = net.nk_to_affiliation(m, D)
        if rewire > 0:
            net.rewire_affiliation(m, edges_node_loc, r)
        edges = net.affiliation_to_node(edges_node_loc)
        # Create strategies
        best_ind_strat = strategy.BestNeighborIndividual(m, edges, sample=3)
        conform_ind_strat = strategy.ConformityIndividual(m, edges, sample=3)
        loc_ind_cons_strat = strategy.LocalIndividualConsensus(m, edges_node_loc)
        loc_conform_ind_strat = strategy.LocalConformityIndividual(m, edges_node_loc, sample=3)
        sys.stdout.write("  Step %d: " % i)
        sys.stdout.write("best-neighbor... ")
        sys.stdout.flush()
        sim = simulator.Simulator(m, edges, best_ind_strat)
        sim.run(50)
        best_perf.append(sim.values[-1])
        best_values.append(sim.values)
        sys.stdout.write("conformity... ")
        sys.stdout.flush()
        sim = simulator.Simulator(m, edges, conform_ind_strat)
        sim.run(50)
        conform_perf.append(sim.values[-1])
        conform_values.append(sim.values)
        sys.stdout.write("loc-consensus... ")
        sys.stdout.flush()
        sim = simulator.Simulator(m, edges, loc_ind_cons_strat)
        sim.run(50)
        loc_cons_perf.append(sim.values[-1])
        loc_cons_values.append(sim.values)
        sys.stdout.write("loc-conformity... ")
        sys.stdout.flush()
        sim = simulator.Simulator(m, edges, loc_conform_ind_strat)
        sim.run(50)
        loc_conform_perf.append(sim.values[-1])
        loc_conform_values.append(sim.values)
        sys.stdout.write("diameter... ")
        sys.stdout.flush()
        next_diameter = 0
        total_path = 0
        path_count = 0
        for n in edges.keys():
            distances = elpalg.get_distances_bfs(edges, n)
            d = max(distances.values())
            total_path += sum(distances.values())
            path_count += len(distances.values()) - 1 # Don't count self
            if d > next_diameter:
                next_diameter = d
        meanpath.append(float(total_path) / float(path_count))
        diameter.append(next_diameter)
        nodes = edges.keys()
        degree.append(sum([len(edges[n]) for n in nodes]) / float(len(nodes)))
        sys.stdout.write("done\n")
        sys.stdout.flush()
# Out:
# Rewire 0.000000
#   Step 0: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 1: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 2: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 3: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 4: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 5: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 6: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 7: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 8: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 9: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 10: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 11: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 12: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 13: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 14: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 15: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 16: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 17: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 18: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 19: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 20: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 21: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 22: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 23: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 24: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 25: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 26: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 27: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 28: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 29: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 30: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 31: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 32: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 33: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 34: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 35: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 36: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 37: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 38: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 39: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 40: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 41: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 42: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 43: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 44: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 45: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 46: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 47: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 48: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.000000
#   Step 49: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 0: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 1: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 2: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 3: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 4: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 5: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 6: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 7: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 8: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 9: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 10: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 11: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 12: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 13: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 14: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 15: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 16: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 17: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 18: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 19: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 20: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 21: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 22: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 23: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 24: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 25: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 26: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 27: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 28: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 29: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 30: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 31: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 32: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 33: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 34: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 35: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 36: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 37: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 38: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 39: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 40: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 41: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 42: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 43: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 44: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 45: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 46: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 47: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 48: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.250000
#   Step 49: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.500000
#   Step 0: best-neighbor... conformity... loc-consensus... loc-conformity... diameter... done
# Rewire 0.500000
#   Step 1: best-neighbor...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0f96e6d7d1b6> in <module>()
#      33         sys.stdout.flush()
#      34         sim = simulator.Simulator(m, edges, best_ind_strat)
# ---> 35         sim.run(50)
#      36         best_perf.append(sim.values[-1])
#      37         best_values.append(sim.values)
#
# /Users/elplatt/NK-Net-Learn/simulator.pyc in run(self, steps)
#      18         next_state = {}
#      19         for i in range(steps):
# ---> 20             next_state = self.strategy.get_next(self.state)
#      21             self.state = next_state
#      22             step_total = 0
#
# /Users/elplatt/NK-Net-Learn/strategy.pyc in get_next(self, states)
#      68         new_states = list(states)
#      69         next_best = self.best.get_next(states)
# ---> 70         next_ind = self.ind.get_next(states)
#      71         for n in range(self.node_count):
#      72             value_best = self.model.get_value(next_best[n])
#
# /Users/elplatt/NK-Net-Learn/strategy.pyc in get_next(self, states)
#      49                 new_state = list(states[n])
#      50                 new_state[i] = 1 - new_state[i]
# ---> 51                 new_value = self.model.get_value(new_state)
#      52                 if new_value > next_value:
#      53                     next_value = new_value
#
# /Users/elplatt/NK-Net-Learn/elp_nkmodel/nk.pyc in get_value(self, state)
#      14         for n in range(self.N):
#      15             label = tuple([state[i] for i in self.dependence[n]])
# ---> 16             try:
#      17                 total_value += self.values[n][label]
#      18             except KeyError:
#
# KeyboardInterrupt:

# %%
meanpath
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b497f59535aa> in <module>()
# ----> 1 meanpath
#
# NameError: name 'meanpath' is not defined

# %%
df = pd.DataFrame({
    "rewire": rewire,
    "degree": degree,
    "mean_path": meanpath,
    "diameter": diameter,
    "conform_perf": conform_perf,
    "best_perf": best_perf,
    "loc_cons": loc_cons_perf,
    "loc_conform": loc_conform_perf
})
df.to_csv("local.csv")

# %%
print "Degree"
print [min(degree), np.mean(degree), max(degree)]
print np.std(degree)
print "Best-neighbor"
print [min(best_perf), np.mean(best_perf), max(best_perf)]
print np.std(best_perf)
print np.std(best_perf)/sqrt(float(len(best_perf)))
print "Conformity"
print [min(conform_perf), np.mean(conform_perf), max(conform_perf)]
print np.std(conform_perf)
print np.std(conform_perf)/sqrt(float(len(conform_perf)))

# %%
plt.figure(figsize=(16,20))
for i in range(5):
    r = float(i) / 4.0
    plt.subplot(5,4,1+i*4)
    plt.title("Best Neighbor")
    plt.ylabel("Rewire = %0.2f" % r)
    for v in best_values[i*20:(i+1)*20]:
        plot(v)
    plt.ylim([0.5,0.8])
    plt.subplot(5,4,2+i*4)
    plt.title("Conformity")
    for v in conform_values[i*20:(i+1)*20]:
        plot(v)
    plt.ylim([0.5,0.8])
    plt.subplot(5,4,3+i*4)
    plt.title("Local Consensus")
    for v in loc_cons_values[i*20:(i+1)*20]:
        plot(v)
    plt.ylim([0.5,0.8])
    plt.subplot(5,4,4+i*4)
    plt.title("Local Conformity")
    for v in loc_conform_values[i*20:(i+1)*20]:
        plot(v)
    plt.ylim([0.5,0.8])
plt.tight_layout()

# %%
plt.figure(figsize=(20,4))
for i in range(5):
    r = float(i) / 4.0
    plt.subplot(1,5,1+i)
    plt.title("Mean perf, n=20, rewire=%0.2f" % r)
    plot([np.mean(x) for x in zip(*best_values[i*20:(i+1)*20])], label="best")
    plot([np.mean(x) for x in zip(*conform_values[i*20:(i+1)*20])], label="conform")
    plot([np.mean(x) for x in zip(*loc_cons_values[i*20:(i+1)*20])], label="loc consensus")
    plot([np.mean(x) for x in zip(*loc_conform_values[i*20:(i+1)*20])], label="loc conform")
    plt.ylim([0.5,0.8])
    plt.legend()
plt.tight_layout()

# %%
plot(df["degree"], df["mean_path"], '.')

# %%
plt.figure(figsize=(16,20))
for i in range(5):
    pr = float(i) / 4.0
    plt.subplot(5,4,1+i*4)
    plot(degree[i*20:(i+1)*20], best_perf[i*20:(i+1)*20], '.')
    r,p = spstats.pearsonr(degree[i*20:(i+1)*20], best_perf[i*20:(i+1)*20])
    plt.title("Best Neighbor, r=%0.2f p=%0.4f" % (r,p))
    plt.ylabel("Rewire = %0.2f" % pr)
    plt.xlabel("Degree")
    plt.subplot(5,4,2+i*4)
    plot(degree[i*20:(i+1)*20], conform_perf[i*20:(i+1)*20], '.')
    r,p = spstats.pearsonr(degree[i*20:(i+1)*20], conform_perf[i*20:(i+1)*20])
    plt.title("Conformity, r=%0.2f p=%0.4f" % (r,p))
    plt.xlabel("Degree")
    plt.subplot(5,4,3+i*4)
    plot(degree[i*20:(i+1)*20], loc_cons_perf[i*20:(i+1)*20], '.')
    r,p = spstats.pearsonr(degree[i*20:(i+1)*20], loc_cons_perf[i*20:(i+1)*20])
    plt.title("Local Consensus, r=%0.2f p=%0.4f" % (r,p))
    plt.xlabel("Degree")
    plt.subplot(5,4,4+i*4)
    plot(degree[i*20:(i+1)*20], loc_conform_perf[i*20:(i+1)*20], '.')
    r,p = spstats.pearsonr(degree[i*20:(i+1)*20], loc_conform_perf[i*20:(i+1)*20])
    plt.title("Local Conformity, r=%0.2f p=%0.4f" % (r,p))
    plt.xlabel("Degree")
plt.tight_layout()

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,4,1)
plot(degree, best_perf, '.')
r,p = spstats.pearsonr(degree, best_perf)
plt.title("Best Neighbor, r=%0.2f p=%0.4f" % (r,p))
plt.xlabel("Degree")
plt.subplot(1,4,2)
plot(degree, conform_perf, '.')
r,p = spstats.pearsonr(degree, conform_perf)
plt.title("Conformity, r=%0.2f p=%0.4f" % (r,p))
plt.xlabel("Degree")
plt.subplot(1,4,3)
plot(degree, loc_cons_perf, '.')
r,p = spstats.pearsonr(degree, loc_cons_perf)
plt.title("Local Consensus, r=%0.2f p=%0.4f" % (r,p))
plt.xlabel("Degree")
plt.subplot(1,4,4)
plot(degree, loc_conform_perf, '.')
r,p = spstats.pearsonr(degree, loc_conform_perf)
plt.title("Local Conformity, r=%0.2f p=%0.4f" % (r,p))
plt.xlabel("Degree")
plt.tight_layout()

# %%
plt.plot(rewire, meanpath)
